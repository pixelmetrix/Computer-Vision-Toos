# %%
from modules.normalization import Normalize

# %%
my_object = Normalize('bb10_5')

# %%
my_object.preprocess()
# Out:
# Processing image: /home/diego/Desktop/Blueberries/Computer-Vision-Toos/Images/Raw_imgs/bb10_5/IMG_7156.JPG
# Processing image: /home/diego/Desktop/Blueberries/Computer-Vision-Toos/Images/Raw_imgs/bb10_5/IMG_8932.JPG
# Processing image: /home/diego/Desktop/Blueberries/Computer-Vision-Toos/Images/Raw_imgs/bb10_5/IMG_7199.JPG
# Processing image: /home/diego/Desktop/Blueberries/Computer-Vision-Toos/Images/Raw_imgs/bb10_5/IMG_7248.JPG
# Processing image: /home/diego/Desktop/Blueberries/Computer-Vision-Toos/Images/Raw_imgs/bb10_5/IMG_6740.JPG
# Processing image: /home/diego/Desktop/Blueberries/Computer-Vision-Toos/Images/Raw_imgs/bb10_5/IMG_7255.JPG
# Preprocessing Successful

# %%
my_object.delete()
