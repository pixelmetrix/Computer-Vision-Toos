# %%
from modules.normalization import Normalize

# %%
my_object = Normalize('bb6_3')

# %%
my_object.preprocess()
# Out:
# Processing image: /home/diego/Desktop/Blueberries/Computer-Vision-Toos/Images/Raw_imgs/bb6_2/2ac0cd9a-10df-4b28-80ff-ad69f190b222_BB6_C_C32_95bd805f.JPG
# Processing image: /home/diego/Desktop/Blueberries/Computer-Vision-Toos/Images/Raw_imgs/bb6_2/2ac0cd9a-10df-4b28-80ff-ad69f190b222_BB6_C_C32_IMG_1744.JPG
# Processing image: /home/diego/Desktop/Blueberries/Computer-Vision-Toos/Images/Raw_imgs/bb6_2/2ac0cd9a-10df-4b28-80ff-ad69f190b222_BB6_C_C32_29adeb12.JPG
# Processing image: /home/diego/Desktop/Blueberries/Computer-Vision-Toos/Images/Raw_imgs/bb6_2/2ac0cd9a-10df-4b28-80ff-ad69f190b222_BB6_C_C34_04c85dde.JPG
# Preprocessing Successful

# %%
my_object.delete()
